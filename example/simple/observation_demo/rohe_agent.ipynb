# %%
# This is self implemented Agent, you can also use ROHE Observation Agent
import qoa4ml.utils.qoa_utils as qutils
from qoa4ml.collector.amqp_collector import AmqpCollector
from qoa4ml.config.configs import AMQPCollectorConfig

config_file = "config/observationConfig.yaml"


observation_config = qutils.load_config(config_file)
print(f"observation_config: {observation_config}")
collector_config = AMQPCollectorConfig(observation_config["collector"]["config"])

observation_collector = AmqpCollector(collector_config)
# Out:
# observation_config: {'collector': {'name': 'amqp_collector', 'connectorType': 'AMQP', 'config': {'end_point': 'localhost', 'exchange_name': 'cain_demo', 'exchange_type': 'topic', 'in_queue': 'collector_1', 'in_routing_key': 'in_routing_key'}}, 'connector': {'name': 'amqp_connector', 'connectorType': 'AMQP', 'config': {'end_point': 'localhost', 'exchange_name': 'cain_demo', 'exchange_type': 'topic', 'out_routing_key': 'out_routing_key'}}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 14
#      12 observation_config = qutils.load_config(config_file)
#      13 print(f"observation_config: {observation_config}")
# ---> 14 collector_config = AMQPCollectorConfig(
#      15     observation_config["collector"]["config"]
#      16 )
#      18 observation_collector = AmqpCollector(collector_config)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given
